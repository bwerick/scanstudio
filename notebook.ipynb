# %%
import flor

# %%
df = flor.dataframe("text")
df
# Out:
#     video                     video_value  frame     frame_value  \
# 0       1  The Plague Recording NIKON.mov      1  0000001470.jpg
# 1       1  The Plague Recording NIKON.mov      2  0000001920.jpg
# 2       1  The Plague Recording NIKON.mov      3  0000000960.jpg
# 3       1  The Plague Recording NIKON.mov      4  0000000180.jpg
# 4       1  The Plague Recording NIKON.mov      5  0000001710.jpg
# ..    ...                             ...    ...             ...
# 75      1  The Plague Recording NIKON.mov     76  0000001440.jpg
# 76      1  The Plague Recording NIKON.mov     77  0000001050.jpg
# 77      1  The Plague Recording NIKON.mov     78  0000001290.jpg
# 78      1  The Plague Recording NIKON.mov     79  0000002160.jpg
# 79      1  The Plague Recording NIKON.mov     80  0000001680.jpg
#
#           projid              tstamp      filename  \
# 0   segmentation 2025-04-03 09:58:40  frame_ocr.py
# 1   segmentation 2025-04-03 09:58:40  frame_ocr.py
# ...

# %%
print(df.iloc[0]['text'])
# Out:
# 8000 rats
# The
# swept the had been
# Plague
# the town. collected,
# had zuthorices There Was wave
# a
# houses were
# a of
# Pus
# year on the accused demand
# une
# that though it coast of for something a
# for the accuad un
# the
# as, But spoke of slacknesss drastic
# while Ricas was neadeng the seracontura
# service had
# nex day moving
# Aher lanch, his wife had seet aunn Groust R un one of 15
# the
# oug
# phenomenon
# one
# collected had
# burea
# the telogram her arrival the phone Abmipat Onice zinght
# Itwas, breathed more only abruptly a
# ended
# nocencing panents clerk in the time invo CONSSOR Code
# when
# freely. trifling
# former had suffered for long bad
# 6
# he however, on this
# number
# hin up He A he WIS poor, Ricex chaged
# lived, parking his car in same day,
# of the aorts and,
# end of the noticed the front of at 0 on
# fee.
# for
# me But this time a
# bent, street. He
# the
# that Dr.
# Thanks doctor, remembering has had an accident.
# arms
# ...

# %%
df.to_csv("erick_demo.csv")
